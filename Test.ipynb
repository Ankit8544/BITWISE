# %% [markdown]
# - Repetition
#     - 4 times: `automated`
#         - try replacing with
#             - systematized
#             - mechanized
#             - computerized
#
#     - 3 times: `developed`
#         - try replacing with
#             - enhanced
#             - expanded
#             - improved
#
# - Spelling & Grammar - 6 errors found
# - Design - 1 issue found
# - Tailoring
#     - Hard Skills
#     - Soft Skills
#     - Action Verbs
#     - Tailored Title

# %% [markdown]
# Brutally evaluate my resume like the world's best ATS Software for the MIS role based on the points I mentioned below, and all other points that are required for a 100% ATS Score
#
# Make sure to check it section by section without mixing the whole thing
# Keep that in Mind - No Clarification, just what is wrong and how to fix that without any other ass hole stuff.
#
# - Content
#     - ATS Parse Rate
#     - Quantifying Impact
#     - Repetition
#     - Spelling & Grammar
#
# - Sections
#     - Essential Sections
#     - Contact Information
#
# - ATS Essentials
#     - File Format & Size
#     - Design
#     - Email Address
#     - Hyperlink in Header
#
# https://www.linkedin.com/in/ankit-sharma-ji
# https://ankit-sharma-07.netlify.app/
